# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Value-oriented consumers - Sheet1.csv')

# %%
print(df.head(5))
# Out:
#    Age    Location            Occupation  Cost_Sensitivity  \
# 0   59       Urban        Business Owner                 4
# 1   49       Urban        Business Owner                 2
# 2   35       Urban  Working Professional                 4
# 3   28  Semi-Urban               Student                 5
# 4   41       Urban  Working Professional                 2
#
#    Fuel_Efficiency_Importance Aware_Govt_Incentives Prefers_EV  \
# 0                           1                   Yes         No
# 1                           1                   Yes         No
# 2                           1                   Yes        Yes
# 3                           2                   Yes        Yes
# 4                           2                   Yes        Yes
#
#    EV_Maintenance_Cost_Awareness  ICE_Total_Cost  EV_Total_Cost
# 0                              1          673687         617351
# 1                              1          769416         653125
# ...

# %%
price_sensitive = df[(df['Cost_Sensitivity'] >= 4) & (df['Fuel_Efficiency_Importance'] >= 4)]

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['ICE_Total_Cost'], color='red', label='ICE TCO', kde=True)
sns.histplot(df['EV_Total_Cost'], color='green', label='EV TCO', kde=True)
plt.title('Total Cost of Ownership: ICE vs EV')
plt.xlabel('TCO (₹)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Aware_Govt_Incentives', data=df)
plt.title('Awareness of Government Incentives for EVs')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Prefers_EV', y='Cost_Sensitivity', data=df)
plt.title('Cost Sensitivity vs Preference for EVs')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Location', hue='Prefers_EV', data=df)
plt.title('Location-wise Preference for EVs')
plt.show()
